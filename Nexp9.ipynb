# %%
import logging
from urllib.parse import urljoin
import requests
from bs4 import BeautifulSoup

logging.basicConfig(
    format='%(asctime)s %(levelname)s:%(message)s',
    level=logging.INFO)

class Crawler:

    def __init__(self, urls=[]):
        self.visited_urls = []
        self.urls_to_visit = urls

    def download_url(self, url):
        return requests.get(url).text

    def get_linked_urls(self, url, html):
        soup = BeautifulSoup(html, 'html.parser')
        for link in soup.find_all('a'):
            path = link.get('href')
            if path and path.startswith('/'):
                path = urljoin(url, path)
            yield path

    def add_url_to_visit(self, url):
        if url not in self.visited_urls and url not in self.urls_to_visit:
            self.urls_to_visit.append(url)

    def crawl(self, url):
        html = self.download_url(url)
        for url in self.get_linked_urls(url, html):
            self.add_url_to_visit(url)

    def run(self):
        while self.urls_to_visit:
            url = self.urls_to_visit.pop(0)
            logging.info(f'Crawling: {url}')
            try:
                self.crawl(url)
            except Exception:
                logging.exception(f'Failed to crawl: {url}')
            finally:
                self.visited_urls.append(url)

if __name__ == '__main__':
    Crawler(urls=['https://www.rottentomatoes.com']).run()
# Out:
# 2022-12-02 11:52:28,040 INFO:Crawling: https://www.rottentomatoes.com
# 2022-12-02 11:52:29,876 INFO:Crawling: https://www.rottentomatoes.com/reset-client
# 2022-12-02 11:52:31,040 INFO:Crawling: https://www.fandango.com/policies/privacy-policy
# 2022-12-02 11:52:33,242 INFO:Crawling: https://www.fandango.com/policies/terms-and-policies
# 2022-12-02 11:52:34,402 INFO:Crawling: https://www.rottentomatoes.com/help_desk
# 2022-12-02 11:52:38,549 INFO:Crawling: #main-page-content
# 2022-12-02 11:52:38,553 ERROR:Failed to crawl: #main-page-content
# Traceback (most recent call last):
#   File "C:\Users\ranja\AppData\Local\Temp\ipykernel_22184\2613259394.py", line 41, in run
#     self.crawl(url)
#   File "C:\Users\ranja\AppData\Local\Temp\ipykernel_22184\2613259394.py", line 32, in crawl
#     html = self.download_url(url)
#   File "C:\Users\ranja\AppData\Local\Temp\ipykernel_22184\2613259394.py", line 17, in download_url
#     return requests.get(url).text
#   File "C:\Users\ranja\AppData\Roaming\Python\Python310\site-packages\requests\api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "C:\Users\ranja\AppData\Roaming\Python\Python310\site-packages\requests\api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "C:\Users\ranja\AppData\Roaming\Python\Python310\site-packages\requests\sessions.py", line 573, in request
#     prep = self.prepare_request(req)
#   File "C:\Users\ranja\AppData\Roaming\Python\Python310\site-packages\requests\sessions.py", line 484, in prepare_request
#     p.prepare(
#   File "C:\Users\ranja\AppData\Roaming\Python\Python310\site-packages\requests\models.py", line 368, in prepare
#     self.prepare_url(url, params)
#   File "C:\Users\ranja\AppData\Roaming\Python\Python310\site-packages\requests\models.py", line 439, in prepare_url
#     raise MissingSchema(
# requests.exceptions.MissingSchema: Invalid URL '#main-page-content': No scheme supplied. Perhaps you meant http://#main-page-content?
# 2022-12-02 11:52:38,621 INFO:Crawling: https://www.rottentomatoes.com/
# 2022-12-02 11:52:39,500 INFO:Crawling: https://www.rottentomatoes.com/search
# 2022-12-02 11:52:40,635 INFO:Crawling: https://www.rottentomatoes.com/about#whatisthetomatometer
# 2022-12-02 11:52:42,085 INFO:Crawling: https://www.rottentomatoes.com/critics
# 2022-12-02 11:52:43,303 INFO:Crawling: https://www.rottentomatoes.com/browse/movies_in_theaters
# 2022-12-02 11:52:45,412 INFO:Crawling: https://www.rottentomatoes.com/browse/opening
# 2022-12-02 11:52:48,094 INFO:Crawling: https://www.rottentomatoes.com/browse/upcoming
# 2022-12-02 11:52:49,882 INFO:Crawling: https://www.rottentomatoes.com/browse/cf-in-theaters
# 2022-12-02 11:52:51,573 INFO:Crawling: https://www.rottentomatoes.com/browse/movies_at_home
# 2022-12-02 11:52:52,907 INFO:Crawling: https://www.rottentomatoes.com/browse/movies_at_home/affiliates:vudu
# 2022-12-02 11:52:54,145 INFO:Crawling: https://www.rottentomatoes.com/browse/movies_at_home/affiliates:netflix
# 2022-12-02 11:52:55,526 INFO:Crawling: https://www.rottentomatoes.com/browse/movies_at_home/affiliates:apple_tv
# 2022-12-02 11:52:56,707 INFO:Crawling: https://www.rottentomatoes.com/browse/movies_at_home/affiliates:amazon_prime
# 2022-12-02 11:52:57,944 INFO:Crawling: https://www.rottentomatoes.com/browse/movies_at_home/sort:popular
# 2022-12-02 11:52:59,140 INFO:Crawling: https://www.rottentomatoes.com/browse/movies_at_home/critics:certified_fresh
# 2022-12-02 11:53:00,605 INFO:Crawling: https://www.rottentomatoes.com/top
